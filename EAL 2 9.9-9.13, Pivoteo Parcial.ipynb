# %%
#9.10
deter,deter1,deter2,deter3=0.0,0.0,0.0,0.0
m0,m1,m2,matriz =[[0,-3,7],[1,2,-1],[5,-2,0]],[[0,-3,7],[1,2,-1],[5,-2,0]],[[0,-3,7],[1,2,-1],[5,-2,0]],[[0,-3,7],[1,2,-1],[5,-2,0]]
b=[2,3,2]

for l in range(3):
    m0[l][0]=b[l]
    m1[l][1]=b[l]
    m2[l][2]=b[l]

def solucion(z,k):
    mp=0
    if k==0:
        mp=(z[1][1]*z[2][2]-z[1][2]*z[2][1])
    if k==1:
        mp=(z[1][0]*z[2][2]-z[1][2]*z[2][0])*(-1)
    if k==2:
        mp=(z[1][0]*z[2][1]-z[1][1]*z[2][0])    
    return (mp)

for i in range (0,3):    
    deter = deter + (matriz[0][i]*solucion(matriz,i))
    deter1 = deter1 + (m0[0][i]*solucion(m0,i))
    deter2 = deter2 + (m1[0][i]*solucion(m1,i))
    deter3 = deter3 + (m2[0][i]*solucion(m2,i))
print "a) Determinante igual a : ", deter
print "b ) -------------------------"
print "x1 igual a : ", deter1/deter
print "x2 igual a : ", deter2/deter
print "x3 igual a : ", deter3/deter
#9.10
m,b,x,n,det,factor,tol,s,er = [],[],[],3,1.0,0.0,0.0,[],0.0

for z in range(0,n):
    m.append([0.0]*n)
    
m[0][0],m[0][1],m[0][2],m[1][0],m[1][1],m[1][2],m[2][0],m[2][1],m[2][2]=0.0,-3.0,7.0,1.0,2.0,-1.0,5.0,-2.0,0.0
b=[2.0,3.0,2.0]
x=[0.0,0.0,0.0]
s=[0.0,0.0,0.0]
def comprobar ():
    b=[2.0,3.0,2.0]
    return b
    
def gauss(m,b,n,x,tol,er):
    for i in range(0,n):
        s[i]=abs(m[i][1])
        for j in range(1,n):
            if (abs(m[i][j])>s[i]):
                s[i]=abs(m[i][j])
    eliminate(m,s,n,b,tol,er)
    if (er!=-1):
        substitute(m,n,b,x)

def eliminate(m,s,n,b,tol,er):
    for k in range(0,n):
        pivot(m,b,s,n,k)
        if (abs(m[k][k]/s[k])<tol):
            er=-1
        for i in range(k+1,n):
            factor = m[i][k]/m[k][k]
            for j in range (k+1,n):
                m[i][j]=m[i][j]-factor*m[k][j]
            b[i]=b[i]-factor*b[k]
    
    if (abs(m[k][k]/s[k])<tol):
        er=-1
        
def pivot(m,b,s,n,k):
    p,k=0,0
    p=k
    big = abs(m[k][k]/s[k])
    for i in range(k+1,n):
        dummy = abs(m[i][k]/s[i])
        if (dummy>big):
            big=dummy
            p=i
    if (p!=k):
        for j in range(k,n):
            dummy=m[p][j]
            m[p][j]=m[k][j]
            m[k][j]=dummy
        dummy=b[p]
        b[p]=b[k]
        b[k]=dummy
        dummy=s[p]
        s[p]=s[k]
        s[k]=dummy
    
print "\nc)"    
def substitute(m,n,b,x):
    x[n-1]=b[n-1]/m[n-1][n-1]
    i=n-1
    while (i>=0):
        suma = 0
        for j in range(i+1,n):
            suma=suma+x[j]*m[i][j]
        x[i]=(b[i]-suma)/m[i][i]
        i -= 1
    for i in range(0,n):
        k=i+1
        print "El valor de X%d es %f"%(k,x[i])
    print "\nd) "
    print " \n Reemplazando en la primera ecuación : ", 0*(x[0])-3*(x[1])+7*x[2], "igual a : ",comprobar()[0]
    print " \n Reemplazando en la segunda ecuación : ", 1*(x[0])+2*(x[1])-1*x[2], "igual a : ",comprobar()[1]
    print " \n Reemplazando en la tercera ecuación : ", 5*(x[0])-2*(x[1])+0*x[2], "igual a : ",comprobar()[2]
        
        
gauss(m,b,n,x,tol,er)

# %%
#9.11
m,b,x,n,det,factor,tol,s,er = [],[],[],3,1.0,0.0,0.0,[],0.0

for z in range(0,n):
    m.append([0.0]*n)
    
m[0][0],m[0][1],m[0][2],m[1][0],m[1][1],m[1][2],m[2][0],m[2][1],m[2][2]=2.0,-6.0,-1.0,-3.0,-1.0,7.0,-8.0,1.0,-2.0
b=[-38.0,-34.0,-20.0]
x=[0.0,0.0,0.0]
s=[0.0,0.0,0.0]
def comprobar ():
    b=[-38.0,-34.0,-20.0]
    return b
    
def gauss(m,b,n,x,tol,er):
    for i in range(0,n):
        s[i]=abs(m[i][1])
        for j in range(1,n):
            if (abs(m[i][j])>s[i]):
                s[i]=abs(m[i][j])
    eliminate(m,s,n,b,tol,er)
    if (er!=-1):
        substitute(m,n,b,x)

def eliminate(m,s,n,b,tol,er):
    for k in range(0,n):
        pivot(m,b,s,n,k)
        if (abs(m[k][k]/s[k])<tol):
            er=-1
        for i in range(k+1,n):
            factor = m[i][k]/m[k][k]
            for j in range (k+1,n):
                m[i][j]=m[i][j]-factor*m[k][j]
            b[i]=b[i]-factor*b[k]
    
    if (abs(m[k][k]/s[k])<tol):
        er=-1
        
def pivot(m,b,s,n,k):
    p,k=0,0
    p=k
    big = abs(m[k][k]/s[k])
    for i in range(k+1,n):
        dummy = abs(m[i][k]/s[i])
        if (dummy>big):
            big=dummy
            p=i
    if (p!=k):
        for j in range(k,n):
            dummy=m[p][j]
            m[p][j]=m[k][j]
            m[k][j]=dummy
        dummy=b[p]
        b[p]=b[k]
        b[k]=dummy
        dummy=s[p]
        s[p]=s[k]
        s[k]=dummy
    
print "\na)"    
def substitute(m,n,b,x):
    x[n-1]=b[n-1]/m[n-1][n-1]
    i=n-1
    while (i>=0):
        suma = 0
        for j in range(i+1,n):
            suma=suma+x[j]*m[i][j]
        x[i]=(b[i]-suma)/m[i][i]
        i -= 1
    for i in range(0,n):
        k=i+1
        print "El valor de X%d es %f"%(k,x[i])
    print "\nb) "
    print " \n Reemplazando en la primera ecuación : ", 2*(x[0])-6*(x[1])-1*x[2], "igual a : ",comprobar()[0]
    print " \n Reemplazando en la segunda ecuación : ", -3*(x[0])-1*(x[1])+7*x[2], "igual a : ",comprobar()[1]
    print " \n Reemplazando en la tercera ecuación : ", -8*(x[0])+1*(x[1])-2*x[2], "igual a : ",comprobar()[2]
        
        
gauss(m,b,n,x,tol,er)

# %%
#9.12

n,cte,m = 3,0,[]
for i in range(0,n):
    m.append([0.0]*(n+1))

m[0][0],m[0][1],m[0][2],m[0][3],m[1][0],m[1][1],m[1][2],m[1][3],m[2][0],m[2][1],m[2][2],m[2][3]=2.0,1,-1,1,5,2,2,-4,3,1,1,5

def comprobar ():
    b=[1.0,-4.0,5.0]
    return b

def unos(m,cte,n):
    temp=0.0
    temp=m[cte][cte]
    for y in range(0,n+1):
        m[cte][y]=m[cte][y]/temp
        
def hacerCeros(m,cte,n):
    for x in range(0,n):
        if (x!=cte):
            c = m[x][cte]
            for z in range(0,n+1):
                m[x][z]=((-1*c)*m[cte][z])+m[x][z]
                
for a in range(0,n):
    unos(m,cte,n)
    hacerCeros(m,cte,n)
    cte += 1
for x in range(0,n):
    print "La variable X%d es: %f"%(x+1,m[x][n])

print " \n Reemplazando en la primera ecuación : ", 2*(m[0][3])+1*(m[1][3])-1*(m[2][3]), "igual a : ",comprobar()[0]
print " \n Reemplazando en la segunda ecuación : ", 5*(m[0][3])+2*(m[1][3])+2*(m[2][3]), "igual a : ",comprobar()[1]
print " \n Reemplazando en la tercera ecuación : ", 3*(m[0][3])+1*(m[1][3])+1*(m[2][3]), "igual a : ",comprobar()[2]

# %%
#9.13
#Eliminación de Gauss Simple
m,r,x,d,y,i,j,k,h,n = [],[],[],0.0,0.0,0,0,0,0,3
for z in range(0,n):
    m.append([0.0]*n)


m[0][0],m[0][1],m[0][2],m[1][0],m[1][1],m[1][2],m[2][0],m[2][1],m[2][2]=1.0,1.0,-1.0,6.0,2.0,2.0,-3.0,4.0,1.0 
r=[-3.0,2.0,1.0]
x=[0.0,0.0,0.0]
def haciaAdelante():
    for i in range(0,n):
        for j in range(i,n):
            if (i==j):
                d = m[i][j]
                for s in range (0,n):
                    m[i][s]=((m[i][s])/d)
                r[i]=((r[i])/d)
            else:
                d=m[j][i]
                for s in range (0,n):
                    m[j][s]=m[j][s]-(d*m[i][s])
                r[j]=r[j]-(d*r[i])
            
def haciaAtras():
    i=n-1
    j=n-1
    while (i>=0):
        y = r[i]
        while (j>=i):
            y=y-x[j]*m[i][j]
            j -= 1
        x[i]=y
        i -= 1
        j=n-1
    for i in range(0,n):
        k=i+1
        print ""
        print "El valor de X%d es %f"%(k,x[i])
haciaAdelante()        
haciaAtras()
#9.13
#Gauss - Jordan
n,cte,m = 3,0,[]
for i in range(0,n):
    m.append([0.0]*(n+1))

m[0][0],m[0][1],m[0][2],m[0][3],m[1][0],m[1][1],m[1][2],m[1][3],m[2][0],m[2][1],m[2][2],m[2][3]=1.0,1.0,-1.0,-3.0,6.0,2.0,2.0,2.0,-3.0,4.0,1.0,1.0 


def unos(m,cte,n):
    temp=0.0
    temp=m[cte][cte]
    for y in range(0,n+1):
        m[cte][y]=m[cte][y]/temp
        
def hacerCeros(m,cte,n):
    for x in range(0,n):
        if (x!=cte):
            c = m[x][cte]
            for z in range(0,n+1):
                m[x][z]=((-1*c)*m[cte][z])+m[x][z]
                
for a in range(0,n):
    unos(m,cte,n)
    hacerCeros(m,cte,n)
    cte += 1
for x in range(0,n):
    print "La variable X%d es: %f"%(x+1,m[x][n])

# %%
#9.9
m,b,x,n,det,factor,tol,s,er = [],[],[],3,1.0,0.0,0.0,[],0.0

for z in range(0,n):
    m.append([0.0]*n)
    
m[0][0],m[0][1],m[0][2],m[1][0],m[1][1],m[1][2],m[2][0],m[2][1],m[2][2]=8.0,2.0,-2.0,10.0,2.0,4.0,12.0,2.0,2.0
b=[-2.0,4.0,6.0]
x=[0.0,0.0,0.0]
s=[0.0,0.0,0.0]
def comprobar ():
    b=[-2.0,4.0,6.0]
    return b
    
def gauss(m,b,n,x,tol,er):
    for i in range(0,n):
        s[i]=abs(m[i][1])
        for j in range(1,n):
            if (abs(m[i][j])>s[i]):
                s[i]=abs(m[i][j])
    eliminate(m,s,n,b,tol,er)
    if (er!=-1):
        substitute(m,n,b,x)

def eliminate(m,s,n,b,tol,er):
    for k in range(0,n):
        pivot(m,b,s,n,k)
        if (abs(m[k][k]/s[k])<tol):
            er=-1
        for i in range(k+1,n):
            factor = m[i][k]/m[k][k]
            for j in range (k+1,n):
                m[i][j]=m[i][j]-factor*m[k][j]
            b[i]=b[i]-factor*b[k]
    
    if (abs(m[k][k]/s[k])<tol):
        er=-1
        
def pivot(m,b,s,n,k):
    p,k=0,0
    p=k
    big = abs(m[k][k]/s[k])
    for i in range(k+1,n):
        dummy = abs(m[i][k]/s[i])
        if (dummy>big):
            big=dummy
            p=i
    if (p!=k):
        for j in range(k,n):
            dummy=m[p][j]
            m[p][j]=m[k][j]
            m[k][j]=dummy
        dummy=b[p]
        b[p]=b[k]
        b[k]=dummy
        dummy=s[p]
        s[p]=s[k]
        s[k]=dummy
    
def substitute(m,n,b,x):
    x[n-1]=b[n-1]/m[n-1][n-1]
    i=n-1
    while (i>=0):
        suma = 0
        for j in range(i+1,n):
            suma=suma+x[j]*m[i][j]
        x[i]=(b[i]-suma)/m[i][i]
        i -= 1
    for i in range(0,n):
        k=i+1
        print ""
        print "El valor de X%d es %f"%(k,x[i])

    print " \n Reemplazando en la primera ecuación : ", 8*(x[0])+2*(x[1])-2*x[2], "igual a : ",comprobar()[0]
    print " \n Reemplazando en la segunda ecuación : ", 10*(x[0])+2*(x[1])+4*x[2], "igual a : ",comprobar()[1]
    print " \n Reemplazando en la tercera ecuación : ", 12*(x[0])+2*(x[1])+2*x[2], "igual a : ",comprobar()[2]
        
        
gauss(m,b,n,x,tol,er)

# %%
#Implementación pseudocódigo Gauss con pivoteo parcial
m,b,x,n,det,factor,tol,s,er = [],[],[],0,1.0,0.0,0.0,[],0.0
n = int(raw_input("Ingrese el numero de incognitas"))
for z in range(0,n):
    m.append([0.0]*n)

for i in range(0,n):
    k=i+1
    b.append(float(raw_input("Ingrese el elemento %d del vector de soluciones: "%k)))
    x.insert(i,0.0)
    s.insert(i,0.0)
    for j in range(0,n):
        h = j+1
        m[i][j] = float(raw_input("Ingrese el elemento %d%d de la matriz de coeficientes: " %(k,h)))
        
def eliminate(m,s,n,b,tol,er):
    for k in range(0,n):
        pivot(m,b,s,n,k)
        if (abs(m[k][k]/s[k])<tol):
            er=-1
        for i in range(k+1,n):
            factor = m[i][k]/m[k][k]
            for j in range (k+1,n):
                m[i][j]=m[i][j]-factor*m[k][j]
            b[i]=b[i]-factor*b[k]
    
    if (abs(m[k][k]/s[k])<tol):
        er=-1
        
def pivot(m,b,s,n,k):
    p,k=0,0
    p=k
    big = abs(m[k][k]/s[k])
    for i in range(k+1,n):
        dummy = abs(m[i][k]/s[i])
        if (dummy>big):
            big=dummy
            p=i
    if (p!=k):
        for j in range(k,n):
            dummy=m[p][j]
            m[p][j]=m[k][j]
            m[k][j]=dummy
        dummy=b[p]
        b[p]=b[k]
        b[k]=dummy
        dummy=s[p]
        s[p]=s[k]
        s[k]=dummy
    
def substitute(m,n,b,x):
    x[n-1]=b[n-1]/m[n-1][n-1]
    i=n-1
    while (i>=0):
        suma = 0
        for j in range(i+1,n):
            suma=suma+x[j]*m[i][j]
        x[i]=(b[i]-suma)/m[i][i]
        i -= 1
    for i in range(0,n):
        k=i+1
        print ""
        print "El valor de X%d es %f"%(k,x[i])
    
def gauss(m,b,n,x,tol,er):
    for i in range(0,n):
        s[i]=abs(m[i][1])
        for j in range(1,n):
            if (abs(m[i][j])>s[i]):
                s[i]=abs(m[i][j])
    eliminate(m,s,n,b,tol,er)
    if (er!=-1):
        substitute(m,n,b,x)
gauss(m,b,n,x,tol,er)
