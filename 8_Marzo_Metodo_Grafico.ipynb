# %%
import matplotlib.pyplot as plt
# %matplotlib inline
t, f1, f2=[],[],[]
for i in range(6):
    x2=(-1.5)*i +9
    x2b=0.5*i +1
    t.append(i)
    f1.append(x2)
    f2.append(x2b)
    if (x2==x2b):
        a=x2

print "La solución para x2 es : "+ str(a)
print "La solución de x1 es : "+str((2*a)-2)

plt.plot(t,f1, linewidth='2.0', label='3x1+2x2=18')
plt.plot(t,f2, linewidth='2.0',label='-x1+2x2=2')
plt.plot((2*a)-2,a, 'cs', label="Punto de corte")
plt.legend(numpoints = 1)
plt.grid(True)
plt.show()
# Out:
# La solución para x2 es : 3.0
# La solución de x1 es : 4.0
