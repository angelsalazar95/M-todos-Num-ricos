# %%
####17.1) Dados los datos  8.8, 9.5, 9.8, 9.4, 10.0, 9.4, 10.1, 9.2, 11.3, 9.4, 10.0, 10.4, 7.9, 
###10.4, 9.8, 9.8, 9.5, 8.9, 8.8, 10.6, 10.1, 9.5, 9.6, 10.2, 8.9. Determine a) la media, b) la desviación estándar,
##c) la varianza, d) el coeficiente de variación, y e) el intervalo de confianza del 95% para la media. 

d=[8.8, 9.5, 9.8, 9.4, 10.0,9.4, 10.1, 9.2, 11.3, 9.4, 10.0, 10.4, 7.9, 10.4, 9.8, 9.8, 9.5, 8.9, 8.8, 10.6, 10.1, 9.5, 9.6, 10.2, 8.9]

def suma ():
    suma=0;
    for i in range(len(d)):
        suma+=d[i]
    return suma

media=suma()/len(d)


def st ():
    res=0
    for j in range (len(d)):
        res+=(d[j]-media)**2
    return res

st=st()
varianza=st/(len(d)-1)
desvest=math.sqrt(varianza)
coevar=(desvest/media)
t1=2.064
L=media-((desvest/(math.sqrt(len(d))))*t1)
U=media+((desvest/(math.sqrt(len(d))))*t1)

print "a) Media igual a : ",media
print "b) Desviación estándar igual a : ",desvest
print "c) Varianza igual a : ", varianza
print "d) Coeficiente de variación igual a : ", coevar
print "e) intervalo de confianza : ", L , "<= u <= ", U

# %%
##17.2) Construya un histograma de los datos del problema 17.1. Use un rango de 7.5 a 11.5 con intervalos de 0.5. 
from matplotlib.pylab import hist,show
import matplotlib.pyplot as plt
# %matplotlib inline
datos=[8.8,9.5,9.8,9.4,10.0,9.4,10.1,9.2,11.3,9.4,10.0,10.4,7.9,10.4,9.8,9.8,9.5,8.9,8.8,10.6,10.1,9.5,9.6,10.2,8.9]
hist(datos,15,(7.5,11.5))
plt.title("Histograma")
plt.ylabel('Frecuencia')
plt.xlabel('Datos')
show()

# %%
#17.3) Dados los datos: 28.65, 26.55, 26.65, 27.65, 27.35, 28.35, 26.85, 28.65, 29.65, 27.85, 27.05, 28.25, 28.35, 26.75,
#27.65, 28.45, 28.65, 28.45, 31.65, 26.35, 27.75, 29.25, 27.65, 28.65, 27.65, 28.55, 27.55, 27.25. Determine a) la media, 
#b) la desviación estándar, c) la varianza, d) el coeficiente de variación, y e) el intervalo de confianza del 90% para la media.
#f ) Construya un histograma. Use un rango de 26 a 32 con incrementos de 0.5. g) Si se supone que la distribución es normal y que 
#la estimación de la desviación estándar es válida, calcule el rango (es decir, los valores inferior y superior) que agrupa al 68% 
#de los datos. Determine si esta es una estimación válida para los datos del problema.
#17.3
d=[28.65, 26.55, 26.65, 27.65, 27.35, 28.35, 26.85, 28.65, 29.65, 27.85, 27.05, 28.25, 28.35, 26.75, 
   27.65, 28.45, 28.65, 28.45, 31.65, 26.35, 27.75, 29.25, 27.65, 28.65, 27.65, 28.55, 27.55, 27.25]
from matplotlib.pylab import hist,show
import matplotlib.pyplot as plt
# %matplotlib inline
def suma ():
    suma=0;
    for i in range(len(d)):
        suma+=d[i]
    return suma

media=suma()/len(d)


def st ():
    res=0
    for j in range (len(d)):
        res+=(d[j]-media)**2
    return res

st=st()
varianza=st/(len(d)-1)
desvest=math.sqrt(varianza)
coevar=(desvest/media)

t1=1.703
L=media-((desvest/(math.sqrt(len(d))))*t1)
U=media+((desvest/(math.sqrt(len(d))))*t1)

print "a) Media igual a : ",media
print "b) Desviación estándar igual a : ",desvest
print "c) Varianza igual a : ", varianza
print "d) Coeficiente de variación igual a : ", coevar
print "e) intervalo de confianza : ", L , "<= u <= ", U
print "g) El rango que agrupa el 68% de los datos es : ", (media-desvest), " y ", (media+desvest)
hist(d, bins=12)
plt.title('Histograma')
show()

# %%
##17.4) Utilice la regresión por mínimos cuadrados para ajustar una línea recta a:   x = [0, 2, 4, 6, 9, 11, 12, 15, 17, 19] & 
#y = [5, 6, 7, 6, 9, 8, 7, 10, 12, 12]. Además de la pendiente y la intersección, calcule el error estándar de la estimación y 
#el coeficiente de correlación. Haga una gráfica de los datos y la línea de regresión. Después repita el problema, pero ahora 
#efectúe la regresión de x versus y, es decir, intercambie las variables. Interprete sus resultados.

import matplotlib.pyplot as plt
import math
xi=[0.0, 2.0, 4.0, 6.0, 9.0, 11.0, 12.0, 15.0, 17.0, 19.0]
yi=[5.0, 6.0, 7.0, 6.0, 9.0, 8.0, 7.0, 10.0, 12.0, 12.0]
# %matplotlib inline
n=len(xi)
mult, sum1,sumax,sumay,t,z=0,0,0,0,[],[]

for i in range (n):
    sumax+=xi[i]
    sumay+=yi[i]
    mult+=xi[i]*yi[i]
    sum1+=xi[i]**2

expo=sumax**2
a1=(n*mult-(sumax*sumay))/(n*sum1-expo)
xmedia=sumax/n
ymedia=sumay/n
a0=ymedia-(a1*xmedia)

for j in range (n+11):
    y=a0+a1*j
    t.append(j)
    z.append(y)
sr=0
for k in range (n):
    sr+=(yi[k]-a0-a1*xi[k])**2

sxy=math.sqrt(sr/(len(xi)-2))
print "Error estándar de la estimación igual a : ", sxy

def suma (a):
    s=0
    for i in range(n):
        s+=a[i]
    return s
def mul (a,b):
    r=0
    for j in range (n):
        r+=a[j]*b[j]
    return r

num=(n*(mul(xi,yi))-(suma(xi)*suma(yi)))
den=(math.sqrt(n*mul(xi, xi)-suma(xi)**2)*math.sqrt(n*mul(yi, yi)-suma(yi)**2))
res=(num)/(den)
print "Coeficiente de correlación igual a : ",res
plt.plot(t,z, label='recta y=a0+a1*x')
plt.plot(xi,yi, 'ro', label='xi,yi')
plt.xlabel('(x)')
plt.ylabel('f(x)')
plt.legend(loc='upper left', numpoints=1)
plt.grid()
plt.show()
#intercambiando vectores
print "Ahora al intercambiar los vectores tenemos:"
import matplotlib.pyplot as plt
import math
xi=[5.0, 6.0, 7.0, 6.0, 9.0, 8.0, 7.0, 10.0, 12.0, 12.0]
yi=[0.0, 2.0, 4.0, 6.0, 9.0, 11.0, 12.0, 15.0, 17.0, 19.0]
# %matplotlib inline
n=len(xi)
mult, sum1,sumax,sumay,t,z=0,0,0,0,[],[]

for i in range (n):
    sumax+=xi[i]
    sumay+=yi[i]
    mult+=xi[i]*yi[i]
    sum1+=xi[i]**2

expo=sumax**2
a1=(n*mult-(sumax*sumay))/(n*sum1-expo)
xmedia=sumax/n
ymedia=sumay/n
a0=ymedia-(a1*xmedia)

for j in range (n+5):
    y=a0+a1*j
    t.append(j)
    z.append(y)
sr=0
for k in range (n):
    sr+=(yi[k]-a0-a1*xi[k])**2

sxy=math.sqrt(sr/(len(xi)-2))
print "Error estándar de la estimación igual a : ", sxy

def suma (a):
    s=0
    for i in range(n):
        s+=a[i]
    return s
def mul (a,b):
    r=0
    for j in range (n):
        r+=a[j]*b[j]
    return r

num=(n*(mul(xi,yi))-(suma(xi)*suma(yi)))
den=(math.sqrt(n*mul(xi, xi)-suma(xi)**2)*math.sqrt(n*mul(yi, yi)-suma(yi)**2))
res=(num)/(den)
print "Coeficiente de correlación igual a : ",res
plt.plot(t,z, label='recta y=a0+a1*x')
plt.plot(xi,yi, 'ro', label='xi,yi')
plt.xlabel('(x)')
plt.ylabel('f(x)')
plt.legend(loc='upper left', numpoints=1)
plt.grid()
plt.show()
print "El coeficiente de correlación es el mismo en ambos casos, porque así se cambien su relación sigue siendo directamente \
proporcional. En el primer caso los datos están menos dispersos comparado con el segundo caso, esto se puede validar comparando\
 el error estándar de cada uno."
# Out:
# Error estándar de la estimación igual a :  1.0650096999
# Coeficiente de correlación igual a :  0.914767284879
# Ahora al intercambiar los vectores tenemos:
# Error estándar de la estimación igual a :  2.76402571072
# Coeficiente de correlación igual a :  0.914767284879
# El coeficiente de correlación es el mismo en ambos casos, porque así se cambien su relación sigue siendo directamente proporcional. En el primer caso los datos están menos dispersos comparado con el segundo caso, esto se puede validar comparando el error estándar de cada uno.

# %%
#17.5) Use la regresión por mínimos cuadrados para ajustar una línea recta a  x=[ 6, 7, 11, 15, 17, 21, 23, 29, 29, 37, 39] & 
#y = [29, 21, 29, 14, 21, 15, 7, 7, 13, 0, 3]. Además de la pendiente y la intersección, calcule el error estándar de la estimación 
#y el coeficiente de correlación. Haga una gráfica de los datos y la línea de regresión. ¿Si otra persona hiciera una medición adicional 
#de x = 10, y = 10, usted pensaría, con base en una evaluación visual y el error estándar, que la medición era válida o inválida?
#Justifique su conclusión. 
import matplotlib.pyplot as plt
import math
# %matplotlib inline
xi=[6, 7, 11, 15, 17, 21, 23, 29, 29, 37, 39, 10]
yi=[29, 21, 29, 14, 21, 15, 7, 7, 13, 0, 3, 10]


n=len(xi)
mult, sum1,sumax,sumay,t,z=0,0,0,0,[],[]

for i in range (n):
    sumax+=xi[i]
    sumay+=yi[i]
    mult+=xi[i]*yi[i]
    sum1+=xi[i]**2

expo=sumax**2
a1=(n*mult-(sumax*sumay))/(n*sum1-expo)
xmedia=sumax/n
ymedia=sumay/n
a0=ymedia-(a1*xmedia)
for j in range (n+25):
    y=a0+a1*j
    t.append(j)
    z.append(y)
sr=0
for k in range (n):
    sr+=(yi[k]-a0-a1*xi[k])**2

sxy=math.sqrt(sr/(len(xi)-2))
print "Error estándar de la estimación igual a : ", sxy

def suma (a):
    s=0
    for i in range(n):
        s+=a[i]
    return s
def mul (a,b):
    r=0
    for j in range (n):
        r+=a[j]*b[j]
    return r

num=(n*(mul(xi,yi))-(suma(xi)*suma(yi)))
den=(math.sqrt(n*mul(xi, xi)-suma(xi)**2)*math.sqrt(n*mul(yi, yi)-suma(yi)**2))
res=(num)/(den)
print "Coeficiente de correlación igual a : ",res
plt.plot(t,z, label='recta y=a0+a1*x')
plt.plot(xi,yi, 'ro', label='xi,yi')
plt.xlabel('(x)')
plt.ylabel('f(x)')
plt.legend(loc='upper right', numpoints=1)
plt.grid()
plt.show()
print "Si se introduce la medición adicional con x=10 y y=10 se puede concluir con base a la gráfica y el error estándar que \
la medición es inválida, debido a un aumento en el error estándar así como también se puede interpretar en la gráfica que es un \
valor atípico."

# %%
#17.6) Con el mismo enfoque que se empleó para obtener las ecuaciones (17.15) y (17.16), obtenga el ajuste por mínimos 
#cuadrados del modelo siguiente: y = a1x + e. Es decir, determine la pendiente que resulta en el ajuste por mínimos
#cuadrados para una línea recta con intersección en el origen. Ajuste los datos siguientes con dicho modelo e ilustre
#el resultado con una gráfica. x= [2, 4, 6, 7, 10, 11, 14, 17, 20] & y =[1, 2, 5, 2, 8, 7, 6, 9, 12]
import matplotlib.pyplot as plt
import math
# %matplotlib inline
xi=[2.0, 4.0, 6.0, 7.0, 10.0, 11.0, 14.0, 17.0, 20.0]
yi=[1.0, 2.0, 5.0, 2.0, 8.0, 7.0, 6.0, 9.0, 12.0]

n=len(xi)
mult, sum1,sumax,sumay,t,z,ly,lx=0,0,0,0,[],[],[],[]

for i in range (n):
    sumax+=xi[i]
    sumay+=yi[i]
    mult+=xi[i]*yi[i]
    sum1+=xi[i]**2

expo=sumax**2
a1=(n*mult-(sumax*sumay))/(n*sum1-expo)
xmedia=sumax/n
ymedia=sumay/n
a0=ymedia-(a1*xmedia)
#print a0, a1
for j in range (n+10):
    y=a0+a1*j
    t.append(j)
    z.append(y)


for k in range (1,n):
    #lny=math.log(a1)+math.log(k)+1
    lny=math.log(z[k])
    ly.append(lny)
    lx.append(math.log(k))
              
#print ly
plt.plot(t,z, label='recta a0+a1*x')
plt.plot(xi,yi, 'h', label='valores iniciales')
plt.plot(lx,ly,'r-', linewidth=3.0, label='ln(y) / ln(x)')
plt.axis([0,18,0,10])
plt.xlabel('(x)')
plt.ylabel('f(x)')
plt.legend(loc='upper left', numpoints=2)
plt.grid()
plt.show()
