# %% [markdown]
# # Script

# %%
import math
g=9.8
m=68.1
c=12.5
cont=0
for t in range (200):
    v=(g*m/c)*(1-(math.pow(math.e,-c*t/m)))
    print "En el tiempo "+str(t)+ ", la velocidad del paracaidasta es:"+str(v)
# Out:
# En el tiempo 0, la velocidad del paracaidasta es:0.0
# En el tiempo 1, la velocidad del paracaidasta es:8.9531822079
# En el tiempo 2, la velocidad del paracaidasta es:16.4049808029
# En el tiempo 3, la velocidad del paracaidasta es:22.6071669095
# En el tiempo 4, la velocidad del paracaidasta es:27.7692914639
# En el tiempo 5, la velocidad del paracaidasta es:32.0657652324
# En el tiempo 6, la velocidad del paracaidasta es:35.6417515631
# En el tiempo 7, la velocidad del paracaidasta es:38.6180709651
# En el tiempo 8, la velocidad del paracaidasta es:41.0952832258
# En el tiempo 9, la velocidad del paracaidasta es:43.1570849869
# En el tiempo 10, la velocidad del paracaidasta es:44.8731375713
# En el tiempo 11, la velocidad del paracaidasta es:46.3014206042
# En el tiempo 12, la velocidad del paracaidasta es:47.4901909486
# En el tiempo 13, la velocidad del paracaidasta es:48.4796131425
# En el tiempo 14, la velocidad del paracaidasta es:49.3031164225
# ...
